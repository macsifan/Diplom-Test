# %%
import requests
import base64
import os
from PIL import Image
import io

# %%
res=[]
json=[]
for index,image in enumerate(os.listdir('test_images')):
    image = open('test_images/'+image, 'rb')
    image_read = image.read()
    image=base64.b64encode(image_read)
    img=image.decode("utf-8")
    json.append({"id":index,
     "image":img})

# %%
len(json)
# Out:
# 9

# %%
json[]
# Out:
# [{'id': 0,
#   'image': '...'},
#  {'id': 1,
#   'image': '...'},
#  {'id': 2,
#   'image': '...'},
#  {'id': 3,
#   'image': '...'},
#  {'id': 4,
#   'image': '...'},
#  {'id': 5,
#   'image': '...'},
#  {'id': 6,
#   'image': '...'},
#  {'id': 7,
#   'image': '...'},
#  {'id': 8,
#   'image': '...'}]

# %%
res=[]
json=[]
for index,image in enumerate(os.listdir('test_images')):
    image = open('test_images/'+image, 'rb')
    image_read = image.read()
    image=base64.b64encode(image_read)
    img=image.decode("utf-8")
    json.append({"id":index+6,
     "image":img})
req=requests.post('http://127.0.0.1:8000/colorize',json=json)

# %%
res=[]
json=[]
for index,image in enumerate(os.listdir('test_images')):
    image = open('test_images/'+image, 'rb')
    image_read = image.read()
    image=base64.b64encode(image_read)
    img=image.decode("utf-8")
    json.append({"id":index+12,
     "image":img})
req=requests.post('http://127.0.0.1:8000/colorize',json=json)

# %%
res=[]
json=[]
for index,image in enumerate(os.listdir('test_images')):
    image = open('test_images/'+image, 'rb')
    image_read = image.read()
    image=base64.b64encode(image_read)
    img=image.decode("utf-8")
    json.append({"id":index+18,
     "image":img})
req=requests.post('http://127.0.0.1:8000/colorize',json=json)

# %%
res=[]
json=[]
for index,image in enumerate(os.listdir('test_images')):
    image = open('test_images/'+image, 'rb')
    image_read = image.read()
    image=base64.b64encode(image_read)
    img=image.decode("utf-8")
    json.append({"id":index+24,
     "image":img})
req=requests.post('http://127.0.0.1:8000/colorize',json=json)

# %%
requests.get('http://127.0.0.1:8000/colorize/{}'.format(req[13:-2])).text
# Out:
# '{"status": "DONE", "result": "as"}'

# %%
# Out:
# '{"status": "IN_PROGRESS"}'

# %%
imgdata = base64.b64decode((image_64_encode))

# %%
stream = io.BytesIO(imgdata)
image = Image.open(stream).convert("RGB")

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x18E4BE88FC8>
